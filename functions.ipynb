# %% [markdown]
# <a href="https://colab.research.google.com/github/noahgift/functions-from-zero/blob/main/functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Styles of Functions

# %%
def simple():pass

# %%
def simple2():
    print("simple")

# %%
simple2()
# Out:
# simple

# %% [markdown]
# ### Most useful

# %%
def my_worker(fruit):
    statement = f"My favorite meal is chicken and {fruit}"
    meals = {"dinner": statement}
    return meals

# %%
meal = my_worker("Apple")

# %%
type(meal)
# Out:
# dict

# %%
meal
# Out:
# {'dinner': 'My favorite meal is chicken and Apple'}

# %%
def human(food):
    consume = food["dinner"]
    return consume

# %%
my_meal=human(meal)
print(f"I want my meal.  It will be: {my_meal}")
# Out:
# I want my meal.  It will be: My favorite meal is chicken and Apple
